# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
iris=pd.read_csv(r'C:\Users\subra\Downloads\IRIS.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.countplot(data=iris,x='species')
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
fig = sns.jointplot(x='sepal_length',y='sepal_width',data=iris)

# %%
fig = sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind="reg")

# %%
fig = sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind="hex")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

sns.FacetGrid(iris,hue='species',height=5)\
.map(plt.scatter,'sepal_length','sepal_width')\
.add_legend()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='species',y='petal_length',data=iris,order=['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth=2.5,orient='v',dodge=False)

# %%
iris.boxplot(by="species",figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(x='species',y='sepal_length',data=iris,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='species',y='sepal_length',data=iris)
fig=sns.stripplot(x='species',y='sepal_length',data=iris,jitter=True,edgecolor='gray')

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.violinplot(x='species',y='sepal_length',data=iris)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='species',y='petal_length',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='petal_width',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='sepal_length',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='sepal_width',data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.pairplot(data=iris,kind='scatter')

# %%
sns.pairplot(iris,hue='species')

# %%
correlation_matrix = iris.drop(columns=['species']).corr()

# Plot the heatmap
fig = plt.gcf()
fig.set_size_inches(10, 7)
sns.heatmap(correlation_matrix, annot=True, cmap='cubehelix', linewidths=1, linecolor='k', square=True, mask=False, vmin=-1, cbar_kws={"orientation": "vertical"}, cbar=True)
plt.show()

# %%
iris.hist(edgecolor='black',linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)

# %%
sns.set(style="darkgrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
custom_palette = ["red","green","blue"]
fig = sns.swarmplot(x='species',y='petal_length',data=iris,palette=custom_palette)

# %%
sns.set(style="whitegrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x="species",y="petal_length",data=iris,inner=None)
ax = sns.swarmplot(x="species",y="petal_length",data=iris,color="white",edgecolor="black")

# %%
fig=sns.lmplot(x="petal_length",y="petal_width",data=iris)

# %%
sns.FacetGrid(iris,hue="species",height=6)\
 .map(sns.kdeplot,"petal_length")\
 .add_legend()
plt.ioff()

# %%
sns.catplot(x="species",y="sepal_length",data=iris,kind='swarm',palette='Set1')
plt.ioff()
plt.show()

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxenplot(x='species',y='sepal_length',data=iris)
plt.show()

# %%
sub = iris[iris['species'] == 'Iris-setosa']  
sns.kdeplot(data=sub[['sepal_length','sepal_width']], shade=True, shade_lowest=False)
plt.title('iris-setosa')
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.show()

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(15,15))

k1=sns.boxplot(x="species", y="petal_length", data=iris,ax=axes[0,0])
k2=sns.violinplot(x='species',y='petal_length',data=iris,ax=axes[0,1])
k3=sns.stripplot(x='species',y='sepal_length',data=iris,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v',ax=axes[1,0])
axes[1,1].hist(iris.petal_length,bins=100)
plt.show()

# %%
iris['species']=iris['species'].astype('category')

# %%
list1=list()
mylabels=list()
for gen in iris.species.cat.categories:
    list1.append(iris[iris.species==gen].sepal_length)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %%
iris.plot.area(y=['sepal_length','sepal_width','petal_length','petal_width'],alpha=0.4,figsize=(12, 6));
plt.show()

# %%
sns.displot(iris['sepal_length'],kde=True,bins=20);
plt.show()
